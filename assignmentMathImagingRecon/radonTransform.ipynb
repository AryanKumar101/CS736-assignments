# %%
import sigpy as sp # Will be used to generate Shepp-Logan phantom
import matplotlib.pyplot as plt

# %%
f = sp.shepp_logan((128, 128), dtype='float')
plt.imshow(f, origin= 'lower')

# %%
def myXrayIntegration():
    pass
